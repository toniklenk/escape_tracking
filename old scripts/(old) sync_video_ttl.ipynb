# %%
import cv2
import os

# %%
os.getcwd()
# Out:
# '/home/max/Documents/escape tracking/scripts'

# %%
cap = cv2.VideoCapture("../data/A1/FH0002 25-11-14 14-37-02.mp4")

# %%
# get frame count
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Total number of frames: {frame_count}")

# get frame rate
frame_rate = cap.get(cv2.CAP_PROP_FPS)
print(f"Frame rate (FPS): {frame_rate}")

# get current frame index
current_frame = int(cap.get(cv2.CAP_PROP_POS_FRAMES))
print(f"Current frame index: {current_frame}")
# Out:
# Total number of frames: 378
# Frame rate (FPS): 40.0
# Current frame index: 0
