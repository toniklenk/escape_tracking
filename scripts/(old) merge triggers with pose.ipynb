# %% [markdown]
# in this notebook, merge cleaned trigger files with cleaned pose files, by concating them into a single dataframe as described
#
# before merging, check if frame number is consistent. this is likely not true for the old video file, but should be correct starting from mouse 5
